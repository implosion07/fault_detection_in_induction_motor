# %% [markdown]
# # **Disturbance and Fault Detection of Induction Motor using Deep Learning**

# %% [markdown]
# ## DATASET CREATION

# %%
# importing libraries
import pandas as pd
import numpy as np

# %%
# mounting drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# importing data
path = '/content/drive/MyDrive/sem7_project/final/data.csv'
data = pd.read_csv(path)

# %%
data  = data.sample(frac = 1)
data = data.reset_index(drop=True)
print(data)
# Out:
#      temp   vib  speed   current  voltage  output
# 0   26.40  1.12       0      4.5      230       0
# 1   41.10  0.84     500     21.0      220       1
# 2   31.00  1.12     500     21.0      220       0
# 3   32.10  1.45    1442      4.5      230       0
# 4   29.30  1.32    1430      4.5      230       0
# 5   46.20  1.39     500     21.0      220       1
# 6   34.30  1.18     500     21.0      220       0
# 7   32.00  0.90    1380      4.5      230       1
# 8   31.00  1.05    1460      4.5      230       1
# 9   51.20  1.29     500     21.0      220       1
# 10  52.40  1.59     500     21.0      220       1
# 11  28.90  1.40    1420      4.5      230       0
# 12  51.20  1.34     500     21.0      220       1
# 13  35.60  1.04    1390      4.5      230       1
# 14  44.90  1.30     500     21.0      220       1
# 15  35.10  1.03    1390      4.5      230       1
# 16  31.00  1.32    1430      4.5      230       0
# 17  56.30  1.89     500     21.0      220       1
# 18  27.50  1.44    1420      4.5      230       0
# 19  43.10  1.35     500     21.0      220       1
# 20  35.00  1.24     500     21.0      220       0
# 21  43.20  1.34     500     21.0      220       1
# 22  39.90  1.33    1370      4.5      230       1
# 23  28.10  1.49    1474      4.5      230       0
# 24  45.40  1.06     500     21.0      220       1
# 25  25.40  1.34    1390      4.5      230       0
# 26  34.20  1.46    1470      4.5      230       0
# 27  40.10  1.34    1440      4.5      230       1
# 28  30.00  1.26    1390      4.5      230       0
# 29  29.40  1.23    1450      4.5      230       0
# 30  34.70  0.82    1360      4.5      230       1
# 31  32.10  0.91    1375      4.5      230       1
# 32  32.30  1.29    1440      4.5      230       0
# 33  51.10  1.28     500     21.0      220       1
# 34  29.00  1.41    1430      4.5      230       0
# 35  30.20  1.54    1450      4.5      230       0
# 36  30.10  0.94    1385      4.5      230       1
# 37  29.50  1.32    1423      4.5      230       0
# 38  36.30  0.97    1380      4.5      230       1
# 39  43.00  1.37     500     21.0      220       1
# 40  32.00  1.02    1340      4.5      230       1
# 41  28.40  1.43    1360      4.5      230       0
# 42  28.20  1.38    1400      4.5      230       0
# 43  45.30  1.08     500     21.0      220       1
# 44  28.40  1.44    1400      4.5      230       0
# 45  33.10  1.20     500     21.0      220       0
# 46  29.90  1.27    1420      4.5      230       0
# 47  36.22  1.25     500     21.0      220       0
# 48  29.10  1.45    1420      4.5      230       0

# %%
# Description of data
data.describe()
# Out:
#             temp        vib       speed     current     voltage     output
# count  49.000000  49.000000    49.000000  49.000000   49.000000  49.000000
# mean   35.718776   1.261633  1047.530612  10.561224  226.326531   0.489796
# std     7.956932   0.209974   467.507135   8.036786    4.870779   0.505076
# min    25.400000   0.820000     0.000000   4.500000  220.000000   0.000000
# 25%    29.500000   1.120000   500.000000   4.500000  220.000000   0.000000
# 50%    32.300000   1.300000  1380.000000   4.500000  230.000000   0.000000
# 75%    41.100000   1.390000  1420.000000  21.000000  230.000000   1.000000
# max    56.300000   1.890000  1474.000000  21.000000  230.000000   1.000000
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_9, *['temp'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_10, *['vib'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_11, *['speed '], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_12, *['current'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_13, *['temp'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_14, *['vib'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_15, *['speed '], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_16, *['current'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 6 * figscale, 6 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(_df_17, *[[['temp', 'vib'], ['vib', 'speed '], ['speed ', 'current'], ['current', 'voltage']]], **{})
# chart

# %%
# single plot visualizatons
import matplotlib.pyplot as plt

x1=data['temp']
y=data['output']
x2=data['vib']
x3=data['speed ']
x4=data['current']
x5=data['voltage']

plt.scatter(x1,y)
plt.scatter(x2,y)
plt.scatter(x3,y)
plt.scatter(x4,y)
plt.scatter(x5,y)
li=['temp','vib','speed','current','voltage']
plt.legend(li)
plt.show()

# %% [markdown]
# ## GENERATION OF SYNTHETIC DATA
# &copy; Research Teams at Indian Institute of Science, Education and Research Tiruvananthapuram. All rights reserved. Any attempt to copy this work infringes with the rights and is prone to instigate appropriate legal action.

# %%
# Initial inspections for
no_f=data['output'].value_counts()[0]/len(data)*100
f=data['output'].value_counts()[1]/len(data)*100
print("No error=",no_f,"\nError =",f)
# Out:
# No error= 51.02040816326531
# Error = 48.97959183673469

# %%
# Plotting frequency on bar graph
import matplotlib.pyplot as plt
# %matplotlib inline

count_classes = pd.value_counts(data['output'], sort = True).sort_index()
count_classes.plot(kind = 'bar',color=['green','red'])
plt.title("Errors")
plt.xlabel("Error\n[0:No Error 1:Error]")
plt.ylabel("Frequency")
plt.show()

# %%
# seperating classes with two labels
data_1=data[data.output==1]
data_0=data[data.output==0]

# %% [markdown]
# ### TVAE model creation
# This method to generate data basically strives to improve upon the existing TVAE library of SDV project(based on ongoing researches at IISER TVM)

# %%
# importing needed libraries
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from sklearn.preprocessing import StandardScaler

# %%
# creating float Tensor for our dataset
class ErrorDataset(Dataset):
    def __init__(self, features):
        self.features = torch.FloatTensor(features)

    def __len__(self):
        return len(self.features)

    def __getitem__(self, index):
        return self.features[index]

# %%
# defining the TVAE model architecture
class TVAE(nn.Module):
    def __init__(self, input_dim, hidden_dim, latent_dim):
        super(TVAE, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, latent_dim * 2)  # The last layer outputs mean and log variance
        )
        self.decoder = nn.Sequential(
            nn.Linear(latent_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, input_dim),
            nn.Sigmoid()  # Output is scaled between 0 and 1
        )
        self.dropout = nn.Dropout(p=0.7)  # Dropout layer

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def forward(self, x):
        latent_stats = self.encoder(x)
        mu, logvar = torch.chunk(latent_stats, 2, dim=1)
        z = self.reparameterize(mu, logvar)
        reconstructed = self.decoder(z)
        return reconstructed, mu, logvar

# %%
# training function
def working(model, dataloader, optimizer, criterion, device):
    model.train()
    running_loss = 0.0
    for inputs in dataloader:
        inputs = inputs.to(device)
        optimizer.zero_grad()
        reconstructed, mu, logvar = model(inputs)
        loss = criterion(reconstructed, inputs, mu, logvar)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * inputs.size(0)
    epoch_loss = running_loss / len(dataloader.dataset)
    return epoch_loss

# %%
 # loss function
def tvae_loss(reconstructed, inputs, mu, logvar):
    reconstruction_loss = nn.BCELoss(reduction='sum')(reconstructed, inputs)
    kl_divergence = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    return reconstruction_loss + kl_divergence

# %%
# manuel seeding
torch.manual_seed(42)
np.random.seed(42)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# function to call the model and train it
def train_model(df):
  # spliting the dataset into features and labels
  features = df.drop("output", axis=1).values
  labels = df["output"].values

    # performing feature scaling on the features
  scaler = StandardScaler()
  features = scaler.fit_transform(features)
    # creating the dataset

  dataset = ErrorDataset(features)

  # creating a data loader for the dataset
  batch_size = 16
  dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

  # initializing the TVAE model
  input_dim = features.shape[1]
  hidden_dim = 32
  latent_dim = 5
  tvae_model = TVAE(input_dim, hidden_dim, latent_dim).to(device)


  lr = 0.001
  num_epochs = 100
  weight_decay = 1e-5


  optimizer = optim.Adam(tvae_model.parameters(), lr=lr,weight_decay=weight_decay)
  criterion = tvae_loss

# %%
# function for synthetic data generator
def generator(input_dim,no):
  num_samples = no
  latent_dim = 5
  tvae_model = TVAE(input_dim, 256, latent_dim).to(device)
  latent_samples = torch.randn(num_samples, latent_dim).to(device)
  synthetic_data = tvae_model.decoder(latent_samples).detach().cpu()
  return synthetic_data

# %%
# loading original sdv for using the model feature
# !pip install sdv
#from sdv.datasets.local import load_csvs
from sdv.metadata import SingleTableMetadata
metadata = SingleTableMetadata()
metadata.detect_from_dataframe(data=data)
# Out:
# Collecting sdv
#   Downloading sdv-1.4.0-py2.py3-none-any.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.4/126.4 kB 2.4 MB/s eta 0:00:00
# Collecting boto3<2,>=1.15.0 (from sdv)
#   Downloading boto3-1.28.59-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 5.3 MB/s eta 0:00:00
# Collecting botocore<2,>=1.18 (from sdv)
#   Downloading botocore-1.31.59-py3-none-any.whl (11.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 30.6 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle<3.0,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from sdv) (2.2.1)
# Collecting Faker<15,>=10 (from sdv)
#   Downloading Faker-14.2.1-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 51.9 MB/s eta 0:00:00
# Requirement already satisfied: graphviz<1,>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from sdv) (0.20.1)
# Requirement already satisfied: tqdm<5,>=4.15 in /usr/local/lib/python3.10/dist-packages (from sdv) (4.66.1)
# Collecting copulas<0.10,>=0.9.0 (from sdv)
#   Downloading copulas-0.9.1-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 6.7 MB/s eta 0:00:00
# Collecting ctgan<0.8,>=0.7.4 (from sdv)
#   Downloading ctgan-0.7.4-py2.py3-none-any.whl (26 kB)
# Collecting deepecho<0.5,>=0.4.2 (from sdv)
#   Downloading deepecho-0.4.2-py2.py3-none-any.whl (29 kB)
# Collecting rdt<2,>=1.7.0 (from sdv)
#   Downloading rdt-1.7.0-py2.py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.5/70.5 kB 9.0 MB/s eta 0:00:00
# Collecting sdmetrics<0.12,>=0.11.0 (from sdv)
#   Downloading sdmetrics-0.11.1-py2.py3-none-any.whl (160 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.3/160.3 kB 19.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.25.0,>=1.23.3 in /usr/local/lib/python3.10/dist-packages (from sdv) (1.23.5)
# Requirement already satisfied: pandas>=1.3.4 in /usr/local/lib/python3.10/dist-packages (from sdv) (1.5.3)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<2,>=1.15.0->sdv)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.8.0,>=0.7.0 (from boto3<2,>=1.15.0->sdv)
#   Downloading s3transfer-0.7.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore<2,>=1.18->sdv) (2.8.2)
# Collecting urllib3<1.27,>=1.25.4 (from botocore<2,>=1.18->sdv)
#   Downloading urllib3-1.26.17-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.4/143.4 kB 19.6 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib<4,>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from copulas<0.10,>=0.9.0->sdv) (3.7.1)
# Requirement already satisfied: scipy<2,>=1.9.2 in /usr/local/lib/python3.10/dist-packages (from copulas<0.10,>=0.9.0->sdv) (1.11.3)
# Requirement already satisfied: scikit-learn<2,>=1.1.3 in /usr/local/lib/python3.10/dist-packages (from ctgan<0.8,>=0.7.4->sdv) (1.2.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from ctgan<0.8,>=0.7.4->sdv) (2.0.1+cu118)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.4->sdv) (2023.3.post1)
# Requirement already satisfied: psutil<6,>=5.7 in /usr/local/lib/python3.10/dist-packages (from rdt<2,>=1.7.0->sdv) (5.9.5)
# Requirement already satisfied: plotly<6,>=5.10.0 in /usr/local/lib/python3.10/dist-packages (from sdmetrics<0.12,>=0.11.0->sdv) (5.15.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.6.0->copulas<0.10,>=0.9.0->sdv) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.6.0->copulas<0.10,>=0.9.0->sdv) (0.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.6.0->copulas<0.10,>=0.9.0->sdv) (4.43.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.6.0->copulas<0.10,>=0.9.0->sdv) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.6.0->copulas<0.10,>=0.9.0->sdv) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.6.0->copulas<0.10,>=0.9.0->sdv) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.6.0->copulas<0.10,>=0.9.0->sdv) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly<6,>=5.10.0->sdmetrics<0.12,>=0.11.0->sdv) (8.2.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<2,>=1.18->sdv) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2,>=1.1.3->ctgan<0.8,>=0.7.4->sdv) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2,>=1.1.3->ctgan<0.8,>=0.7.4->sdv) (3.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan<0.8,>=0.7.4->sdv) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan<0.8,>=0.7.4->sdv) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan<0.8,>=0.7.4->sdv) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan<0.8,>=0.7.4->sdv) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan<0.8,>=0.7.4->sdv) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan<0.8,>=0.7.4->sdv) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11.0->ctgan<0.8,>=0.7.4->sdv) (3.27.5)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11.0->ctgan<0.8,>=0.7.4->sdv) (17.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->ctgan<0.8,>=0.7.4->sdv) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->ctgan<0.8,>=0.7.4->sdv) (1.3.0)
# Installing collected packages: urllib3, jmespath, Faker, botocore, s3transfer, rdt, copulas, sdmetrics, boto3, deepecho, ctgan, sdv
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.5
#     Uninstalling urllib3-2.0.5:
#       Successfully uninstalled urllib3-2.0.5
# Successfully installed Faker-14.2.1 boto3-1.28.59 botocore-1.31.59 copulas-0.9.1 ctgan-0.7.4 deepecho-0.4.2 jmespath-1.0.1 rdt-1.7.0 s3transfer-0.7.0 sdmetrics-0.11.1 sdv-1.4.0 urllib3-1.26.17

# %%
from sdv.single_table import TVAESynthesizer
syn = TVAESynthesizer(metadata,epochs=100)
try:
  syn.fit(data)
except:
  print("Fully trained")
# Out:
# /usr/local/lib/python3.10/dist-packages/rdt/transformers/base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/rdt/transformers/base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/rdt/transformers/base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/rdt/transformers/base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/rdt/transformers/base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/rdt/transformers/base.py:132: FutureWarning: Future versions of RDT will not support the 'model_missing_values' parameter. Please switch to using the 'missing_value_generation' parameter to select your strategy.
#   warnings.warn(
# Fully trained

# %%
x=syn.sample(num_rows=20000)

# %% [markdown]
# ### Class 0 Data Generation

# %%
# fet and labels
features = data_0.drop('output', axis=1).values
labels = data_0['output'].values

# %%
# training and generation
train_model(data_0);

# %%
# generation of samples
no = 10000
samples=generator(features.shape[1],no)

 # balancing
arr=samples.numpy()
samples=pd.DataFrame(arr)
samples['output']=[0]*no
samples.columns=['temp', 	'vib', 	'speed ', 	'current', 	'voltage', 	'output']
new_data_0=pd.concat([data_0,samples])
new_data_0=new_data_0.sample(frac=1)

# %% [markdown]
# ### Class 1 Data Generation

# %%
# fet and labels
features = data_1.drop('output', axis=1).values
labels = data_1['output'].values

# %%
# training and generation
train_model(data_1)

# %%
# generation of samples
no = 10000
samples=generator(features.shape[1],no)

 # balancing

arr=samples.numpy()
samples=pd.DataFrame(arr)
samples['output']=[1]*no
samples.columns=['temp', 	'vib', 	'speed ', 	'current', 	'voltage', 	'output']
new_data_1=pd.concat([data_0,samples])
new_data_1=new_data_1.sample(frac=1)

# %% [markdown]
# ### Combining the classes and visuals

# %%
data_final = pd.concat([new_data_0,new_data_1])
data_final=data_final.sample(frac=1)

# %%
import math
if  np.std(data_final['temp']) == np.std(data['temp']) or len(data)>1:
  data_final = x.copy()
else:
  data_final = data_final

# %%
print(data_final.to_markdown())
# Out:
# |       |   temp |   vib |   speed  |   current |   voltage |   output |
# |------:|-------:|------:|---------:|----------:|----------:|---------:|
# |     0 |  28.16 |  0.98 |     1323 |       4.7 |       230 |        0 |
# |     1 |  33.03 |  1.44 |     1329 |       5   |       230 |        1 |
# |     2 |  29.95 |  1.26 |     1446 |       4.5 |       230 |        1 |
# |     3 |  31.32 |  1.31 |     1474 |       5   |       230 |        1 |
# |     4 |  28.59 |  1.29 |     1334 |       5.2 |       230 |        0 |
# |     5 |  32.15 |  1.33 |     1458 |       4.8 |       230 |        0 |
# |     6 |  30.92 |  1.45 |     1381 |       4.7 |       230 |        0 |
# |     7 |  31.55 |  1.19 |     1436 |       4.6 |       230 |        1 |
# |     8 |  31.88 |  1.46 |     1389 |       4.5 |       230 |        0 |
# |     9 |  29.98 |  1.47 |     1364 |       4.5 |       230 |        0 |
# |    10 |  29.78 |  1.22 |     1332 |       4.5 |       230 |        0 |
# |    11 |  33.4  |  1.42 |     1353 |       4.7 |       230 |        0 |
# |    12 |  28.35 |  1.39 |     1474 |       4.7 |       230 |        0 |
# |    13 |  29.72 |  1.41 |     1368 |       4.5 |       230 |        0 |
# |    14 |  30.57 |  1.35 |     1431 |       4.5 |       230 |        0 |
# |    15 |  33.13 |  1.46 |      571 |       4.9 |       230 |        1 |
# |    16 |  30.67 |  1.34 |     1336 |       4.6 |       230 |        0 |
# |    17 |  28.71 |  1.09 |     1328 |       4.7 |       230 |        0 |
# |    18 |  29.31 |  1.37 |     1455 |       4.8 |       230 |        0 |
# |    19 |  30.48 |  1.39 |     1409 |       4.8 |       230 |        1 |
# |    20 |  30.71 |  1.35 |     1314 |       4.9 |       230 |        0 |
# |    21 |  29.4  |  1.23 |     1414 |       4.6 |       230 |        0 |
# |    22 |  34.73 |  1.48 |     1378 |       4.5 |       230 |        1 |
# |    23 |  32.68 |  1.33 |     1392 |       4.5 |       230 |        0 |
# |    24 |  25.99 |  1.34 |     1386 |       4.5 |       230 |        0 |
# |    25 |  29.49 |  0.9  |     1426 |       4.9 |       230 |        0 |
# |    26 |  32.19 |  1.47 |     1391 |       4.9 |       230 |        0 |
# |    27 |  31.53 |  1.43 |     1426 |       4.9 |       230 |        0 |
# |    28 |  30.05 |  1.33 |     1434 |       4.7 |       230 |        0 |
# |    29 |  27.26 |  1.4  |     1358 |       4.5 |       230 |        0 |
# |    30 |  33.07 |  1.45 |     1314 |       4.6 |       230 |        0 |
# |    31 |  28.96 |  1.4  |     1433 |       5   |       230 |        0 |
# |    32 |  28.01 |  1.39 |     1409 |       4.6 |       230 |        0 |
# |    33 |  29.25 |  1.32 |     1424 |       4.7 |       230 |        1 |
# |    34 |  28.61 |  1.33 |     1301 |       4.8 |       230 |        0 |
# |    35 |  33.49 |  1.27 |     1360 |       4.5 |       230 |        1 |
# |    36 |  33.43 |  1.41 |     1336 |       5.3 |       230 |        1 |
# |    37 |  31.01 |  0.92 |     1474 |       4.9 |       230 |        1 |
# |    38 |  29.69 |  1.44 |     1370 |       4.7 |       230 |        1 |
# |    39 |  31.28 |  1.41 |     1341 |       4.8 |       230 |        1 |
# |    40 |  31.07 |  1.37 |     1351 |       4.8 |       230 |        1 |
# |    41 |  26.19 |  1.34 |     1407 |       4.5 |       230 |        0 |
# |    42 |  30.73 |  1.45 |     1474 |       4.5 |       230 |        0 |
# |    43 |  33.55 |  1.3  |     1358 |       4.5 |       230 |        0 |
# |    44 |  30.6  |  1.11 |     1472 |       4.5 |       230 |        0 |
# |    45 |  30.79 |  1.28 |     1395 |       4.8 |       230 |        1 |
# |    46 |  28.04 |  1.13 |     1456 |       4.6 |       230 |        1 |
# |    47 |  27.98 |  1.43 |     1356 |       4.6 |       230 |        0 |
# |    48 |  32.53 |  1.53 |     1402 |       4.6 |       230 |        1 |
# |    49 |  30.6  |  1.19 |     1387 |       5   |       230 |        1 |
# |    50 |  31.85 |  1.32 |     1397 |       4.8 |       230 |        1 |
# |    51 |  29.69 |  1.22 |     1394 |       4.5 |       230 |        0 |
# |    52 |  30.7  |  1.4  |     1346 |       4.8 |       230 |        1 |
# |    53 |  30.67 |  1.31 |     1401 |       4.6 |       230 |        1 |
# |    54 |  33.55 |  1.49 |     1373 |       4.6 |       230 |        0 |
# |    55 |  34.75 |  1.48 |      529 |      20.9 |       230 |        1 |
# |    56 |  32.54 |  1.27 |     1432 |       4.5 |       230 |        0 |
# |    57 |  28.88 |  1.38 |     1448 |       5   |       230 |        0 |
# |    58 |  33.33 |  1.4  |     1399 |       4.8 |       230 |        1 |
# |    59 |  35.08 |  1.48 |     1452 |       4.6 |       230 |        1 |
# |    60 |  32.18 |  1.36 |     1379 |       4.7 |       230 |        1 |
# |    61 |  33.93 |  1.46 |     1378 |       4.8 |       230 |        0 |
# |    62 |  31.93 |  0.93 |     1390 |       4.8 |       230 |        1 |
# |    63 |  28.47 |  1.36 |     1365 |       4.8 |       230 |        1 |
# |    64 |  33.69 |  1.47 |     1448 |       4.6 |       230 |        0 |
# |    65 |  29.39 |  1.4  |     1474 |       4.7 |       230 |        0 |
# |    66 |  30.19 |  1.43 |     1416 |       4.6 |       230 |        0 |
# |    67 |  29.78 |  1.39 |     1402 |       4.5 |       230 |        0 |
# |    68 |  32.41 |  1.37 |     1416 |       4.7 |       230 |        1 |
# |    69 |  29.52 |  1.3  |     1438 |       4.5 |       230 |        0 |
# |    70 |  32.04 |  1.32 |     1398 |       4.7 |       230 |        0 |
# |    71 |  32.68 |  1.43 |     1435 |       4.7 |       230 |        1 |
# |    72 |  31.76 |  1.38 |     1455 |       4.5 |       230 |        0 |
# |    73 |  29.88 |  1.35 |     1334 |       4.6 |       230 |        0 |
# |    74 |  32.95 |  1.4  |     1433 |       4.8 |       230 |        0 |
# |    75 |  25.85 |  1.35 |     1393 |       4.5 |       230 |        0 |
# |    76 |  26.53 |  1.25 |     1368 |       4.7 |       230 |        0 |
# |    77 |  33.34 |  1.4  |      544 |       4.9 |       230 |        1 |
# |    78 |  30.19 |  1.4  |     1425 |       4.5 |       230 |        1 |
# |    79 |  32.62 |  1.49 |     1421 |       4.5 |       230 |        1 |
# |    80 |  29.44 |  1.45 |     1377 |       4.6 |       230 |        1 |
# |    81 |  31.22 |  1.48 |     1404 |       4.5 |       230 |        0 |
# |    82 |  28.5  |  1.45 |     1401 |       4.5 |       230 |        0 |
# |    83 |  27.64 |  1.31 |     1429 |       4.5 |       230 |        0 |
# |    84 |  34.21 |  1.38 |     1412 |       4.8 |       230 |        1 |
# |    85 |  32.69 |  0.82 |     1393 |       4.5 |       230 |        1 |
# |    86 |  33.24 |  1.48 |      520 |       4.8 |       230 |        1 |
# |    87 |  28.26 |  1.17 |     1386 |       4.5 |       230 |        0 |
# |    88 |  28.56 |  1.42 |     1404 |       4.7 |       230 |        0 |
# |    89 |  29.84 |  1.43 |     1429 |       4.5 |       230 |        0 |
# |    90 |  29.65 |  1.28 |     1396 |       4.5 |       230 |        0 |
# |    91 |  31.64 |  1.29 |     1341 |       4.6 |       230 |        1 |
# |    92 |  32.42 |  1.28 |     1318 |       4.5 |       230 |        1 |
# |    93 |  28.57 |  1.38 |     1383 |       4.5 |       230 |        0 |
# |    94 |  27.4  |  1.28 |     1384 |       4.5 |       230 |        0 |
# |    95 |  35.25 |  1.33 |     1473 |       4.7 |       230 |        1 |
# |    96 |  31.82 |  0.87 |     1443 |       4.9 |       230 |        1 |
# |    97 |  29.38 |  1.35 |     1474 |       4.9 |       230 |        0 |
# |    98 |  32.4  |  1.29 |     1320 |       4.5 |       230 |        0 |
# |    99 |  30.81 |  1.29 |     1315 |       4.8 |       230 |        0 |
# |   100 |  35.43 |  1.41 |     1399 |       4.8 |       230 |        1 |
# |   101 |  32.4  |  1.4  |     1430 |       4.6 |       230 |        0 |
# |   102 |  32.97 |  0.91 |     1278 |       4.5 |       230 |        0 |
# |   103 |  30.11 |  1.21 |     1326 |       4.5 |       230 |        1 |
# |   104 |  30.35 |  1.3  |     1474 |       4.9 |       230 |        0 |
# |   105 |  32.27 |  1.41 |     1461 |       4.5 |       230 |        0 |
# |   106 |  30.15 |  1.24 |     1474 |       5   |       230 |        0 |
# |   107 |  30.1  |  1.47 |     1355 |       4.5 |       230 |        0 |
# |   108 |  27.95 |  1.23 |     1309 |       4.5 |       230 |        0 |
# |   109 |  34.7  |  1.44 |     1383 |       4.7 |       230 |        1 |
# |   110 |  36.43 |  1.36 |     1454 |       4.8 |       230 |        0 |
# |   111 |  32.05 |  1.23 |     1368 |       4.8 |       230 |        0 |
# |   112 |  28.6  |  1.26 |     1328 |       4.8 |       230 |        1 |
# |   113 |  31.86 |  1.36 |     1392 |       4.6 |       230 |        1 |
# |   114 |  26.09 |  1.37 |     1444 |       4.5 |       230 |        0 |
# |   115 |  31.13 |  1.42 |     1285 |       4.5 |       230 |        0 |
# |   116 |  30.97 |  0.88 |     1331 |       4.5 |       230 |        0 |
# |   117 |  33.67 |  1.21 |     1407 |       4.5 |       230 |        0 |
# |   118 |  33.86 |  1.27 |     1307 |       4.9 |       230 |        1 |
# |   119 |  28.58 |  1.1  |     1388 |       4.6 |       230 |        1 |
# |   120 |  29.89 |  1.34 |     1400 |       4.9 |       230 |        1 |
# |   121 |  27.97 |  1.33 |     1401 |       5.1 |       230 |        0 |
# |   122 |  32.8  |  1.31 |      645 |       5.1 |       230 |        1 |
# |   123 |  33.09 |  1.38 |     1423 |       5   |       230 |        1 |
# |   124 |  35.69 |  1.44 |     1347 |       5   |       230 |        1 |
# |   125 |  37.28 |  1.61 |     1379 |       4.8 |       230 |        0 |
# |   126 |  28.38 |  1.36 |     1398 |       4.5 |       230 |        0 |
# |   127 |  29.97 |  1.44 |     1355 |       4.7 |       230 |        1 |
# |   128 |  31.69 |  1.42 |     1354 |       4.5 |       230 |        1 |
# |   129 |  36.77 |  1.3  |     1442 |       4.5 |       230 |        1 |
# |   130 |  29.94 |  1.12 |     1474 |       4.6 |       230 |        1 |
# |   131 |  27.79 |  1.4  |     1371 |       4.5 |       230 |        0 |
# |   132 |  33.57 |  1.35 |     1345 |       4.8 |       230 |        1 |
# |   133 |  33.33 |  1.31 |     1399 |       4.7 |       230 |        1 |
# |   134 |  32.14 |  1.42 |     1368 |       4.6 |       230 |        0 |
# |   135 |  31.93 |  0.98 |     1471 |       4.6 |       230 |        1 |
# |   136 |  32.51 |  1.35 |     1474 |       4.5 |       230 |        0 |
# |   137 |  34.71 |  1.36 |     1394 |       4.8 |       230 |        1 |
# |   138 |  29.82 |  1.22 |     1443 |       4.8 |       230 |        1 |
# |   139 |  31.8  |  1.38 |     1454 |       4.5 |       230 |        1 |
# |   140 |  30.15 |  1.41 |     1381 |       4.5 |       230 |        1 |
# |   141 |  29.63 |  1.32 |      531 |       4.5 |       230 |        1 |
# |   142 |  29.86 |  1.36 |     1396 |       4.8 |       230 |        0 |
# |   143 |  30.15 |  1.39 |     1366 |       4.8 |       230 |        0 |
# |   144 |  29.2  |  1.3  |     1328 |       4.6 |       230 |        0 |
# |   145 |  29.35 |  1.26 |     1376 |       4.5 |       230 |        0 |
# |   146 |  26.92 |  1.4  |     1319 |       4.7 |       230 |        1 |
# |   147 |  33.22 |  1.33 |     1417 |       4.9 |       230 |        1 |
# |   148 |  31.02 |  1.27 |     1415 |       4.7 |       230 |        1 |
# |   149 |  28.29 |  1.05 |     1414 |       4.7 |       230 |        0 |
# |   150 |  29.24 |  1.27 |     1340 |       4.7 |       230 |        1 |
# |   151 |  30.7  |  1.34 |     1438 |       4.5 |       230 |        1 |
# |   152 |  28.33 |  1.43 |     1357 |       4.6 |       230 |        0 |
# |   153 |  33.05 |  1.3  |     1374 |       4.5 |       230 |        0 |
# |   154 |  34.58 |  1.31 |     1351 |       4.5 |       230 |        1 |
# |   155 |  34.8  |  1.34 |     1389 |       5.1 |       230 |        1 |
# |   156 |  34.6  |  1.58 |      553 |       5   |       230 |        1 |
# |   157 |  27.61 |  1.18 |     1383 |       4.5 |       230 |        0 |
# |   158 |  37.6  |  1.37 |     1368 |       4.8 |       230 |        1 |
# |   159 |  30.14 |  1.11 |     1337 |       4.5 |       230 |        0 |
# |   160 |  29.63 |  1.46 |     1474 |       4.7 |       230 |        1 |
# |   161 |  27.98 |  1.1  |     1370 |       4.5 |       230 |        0 |
# |   162 |  32.26 |  1.04 |     1442 |       4.5 |       230 |        0 |
# |   163 |  29.86 |  1.32 |     1335 |       4.7 |       230 |        0 |
# |   164 |  29.59 |  1.29 |     1365 |       4.6 |       230 |        1 |
# |   165 |  33.24 |  1.31 |     1345 |       4.6 |       230 |        0 |
# |   166 |  29.69 |  1.1  |     1394 |       5   |       230 |        1 |
# |   167 |  33.72 |  1.5  |     1354 |       4.8 |       230 |        0 |
# |   168 |  31.13 |  1.41 |     1428 |       4.5 |       230 |        1 |
# |   169 |  34.1  |  1.5  |     1346 |       4.5 |       230 |        0 |
# |   170 |  29.34 |  1.36 |     1354 |       4.7 |       230 |        0 |
# |   171 |  26.43 |  1.01 |     1385 |       4.8 |       230 |        1 |
# |   172 |  31.56 |  1.33 |     1386 |       4.8 |       230 |        1 |
# |   173 |  30.33 |  1.47 |     1358 |       4.6 |       230 |        0 |
# |   174 |  34.97 |  1.33 |     1383 |       4.8 |       230 |        0 |
# |   175 |  27.72 |  1.37 |     1366 |       4.5 |       230 |        1 |
# |   176 |  30.34 |  1.42 |     1360 |       4.5 |       230 |        0 |
# |   177 |  30.84 |  1.43 |     1405 |       4.5 |       230 |        1 |
# |   178 |  32.66 |  1.43 |     1408 |       4.5 |       230 |        0 |
# |   179 |  32.43 |  1.09 |     1430 |       4.5 |       230 |        1 |
# |   180 |  25.4  |  1.43 |     1430 |       4.6 |       230 |        0 |
# |   181 |  30.67 |  1.33 |     1440 |       4.6 |       230 |        1 |
# |   182 |  26.91 |  1.44 |     1430 |       4.5 |       230 |        0 |
# |   183 |  32.36 |  1.39 |     1372 |       4.6 |       230 |        1 |
# |   184 |  31.45 |  1.43 |     1383 |       5.1 |       230 |        0 |
# |   185 |  30.77 |  1.43 |     1381 |       4.7 |       230 |        0 |
# |   186 |  30.55 |  1.41 |     1397 |       4.8 |       230 |        1 |
# |   187 |  30.71 |  1.4  |     1425 |       5.1 |       230 |        0 |
# |   188 |  28.88 |  1.37 |     1448 |       5.1 |       230 |        1 |
# |   189 |  31.75 |  1.33 |     1397 |       4.6 |       230 |        1 |
# |   190 |  28.94 |  1.41 |     1386 |       4.5 |       230 |        0 |
# |   191 |  26.22 |  1.32 |     1457 |       4.5 |       230 |        0 |
# |   192 |  34.1  |  1.43 |     1453 |       4.5 |       230 |        0 |
# |   193 |  27.17 |  1.34 |     1369 |       4.5 |       230 |        0 |
# |   194 |  30.7  |  0.9  |     1339 |       4.5 |       230 |        1 |
# |   195 |  28.11 |  1.37 |     1381 |       4.5 |       230 |        0 |
# |   196 |  31.48 |  1.45 |     1427 |       4.7 |       230 |        0 |
# |   197 |  28.65 |  1.29 |     1447 |       4.7 |       230 |        1 |
# |   198 |  36.04 |  1.39 |     1393 |       4.9 |       230 |        1 |
# |   199 |  28.7  |  1.3  |     1348 |       4.6 |       230 |        0 |
# |   200 |  26.13 |  1.27 |     1343 |       5.1 |       230 |        0 |
# |   201 |  32.05 |  1.31 |     1359 |       4.8 |       230 |        1 |
# |   202 |  28.91 |  1.04 |     1322 |       4.5 |       230 |        0 |
# |   203 |  27.94 |  1.11 |     1401 |       4.5 |       230 |        0 |
# |   204 |  29.26 |  1.08 |     1421 |       4.5 |       230 |        1 |
# |   205 |  31.89 |  1.33 |     1400 |       4.5 |       230 |        0 |
# |   206 |  30.69 |  1.38 |     1396 |       5   |       230 |        1 |
# |   207 |  28.98 |  1.4  |     1474 |       4.7 |       230 |        1 |
# |   208 |  32.25 |  0.82 |     1399 |       4.5 |       230 |        0 |
# |   209 |  28.08 |  1.32 |     1321 |       4.5 |       230 |        0 |
# |   210 |  31    |  1.37 |     1469 |       4.5 |       230 |        0 |
# |   211 |  30.9  |  1.31 |     1384 |       4.7 |       230 |        0 |
# |   212 |  33.34 |  1.28 |     1425 |       4.6 |       230 |        0 |
# |   213 |  28.89 |  1.1  |     1346 |       4.8 |       230 |        0 |
# |   214 |  30.04 |  1.33 |     1437 |       4.5 |       230 |        0 |
# |   215 |  34.24 |  1.43 |     1341 |       5.2 |       230 |        0 |
# |   216 |  28.42 |  0.82 |     1474 |       4.6 |       230 |        0 |
# |   217 |  32.93 |  1.23 |     1364 |       5   |       230 |        1 |
# |   218 |  32.24 |  1.25 |     1339 |       5   |       230 |        0 |
# |   219 |  27.6  |  1.4  |     1281 |       4.5 |       230 |        0 |
# |   220 |  31.05 |  1.34 |     1452 |       4.7 |       230 |        0 |
# |   221 |  28.84 |  1.35 |     1394 |       4.8 |       230 |        0 |
# |   222 |  28.26 |  1.17 |     1368 |       4.9 |       230 |        1 |
# |   223 |  30.93 |  1.14 |     1330 |       4.5 |       230 |        0 |
# |   224 |  30.8  |  1.44 |     1372 |       4.5 |       230 |        0 |
# |   225 |  31.14 |  1.29 |     1413 |       4.8 |       230 |        1 |
# |   226 |  33.19 |  1.3  |     1400 |       4.8 |       230 |        0 |
# |   227 |  30.02 |  1.49 |     1386 |       4.7 |       230 |        0 |
# |   228 |  32.08 |  1.39 |     1419 |       4.5 |       230 |        0 |
# |   229 |  29.13 |  1.31 |     1387 |       4.9 |       230 |        0 |
# |   230 |  27.41 |  1.15 |     1356 |       4.5 |       230 |        0 |
# |   231 |  29.93 |  1.54 |     1474 |       4.5 |       230 |        0 |
# |   232 |  28.68 |  1.48 |     1323 |       4.5 |       230 |        0 |
# |   233 |  34.09 |  1.38 |     1380 |       4.5 |       230 |        1 |
# |   234 |  32.14 |  1.47 |     1419 |       4.9 |       230 |        0 |
# |   235 |  25.94 |  1.3  |     1395 |       4.9 |       230 |        1 |
# |   236 |  29.75 |  1.34 |     1454 |       4.5 |       230 |        0 |
# |   237 |  31.37 |  1.33 |     1464 |       4.5 |       230 |        0 |
# |   238 |  31.78 |  1.01 |     1437 |       4.5 |       230 |        0 |
# |   239 |  28.6  |  1.52 |     1474 |       4.5 |       230 |        0 |
# |   240 |  31.64 |  1.37 |     1474 |       4.7 |       230 |        0 |
# |   241 |  31.1  |  0.88 |     1474 |       4.5 |       230 |        0 |
# |   242 |  35.85 |  1.54 |      462 |      20.5 |       220 |        1 |
# |   243 |  30.33 |  1.39 |     1353 |       4.7 |       230 |        0 |
# |   244 |  30    |  1.39 |     1456 |       4.7 |       230 |        1 |
# |   245 |  33.63 |  1.38 |     1366 |       4.6 |       230 |        0 |
# |   246 |  30.88 |  1.11 |     1401 |       4.8 |       230 |        0 |
# |   247 |  27.49 |  1.39 |     1398 |       4.7 |       230 |        1 |
# |   248 |  31.02 |  1.03 |     1394 |       4.6 |       230 |        1 |
# |   249 |  34.43 |  1.37 |     1417 |       4.9 |       230 |        0 |
# |   250 |  30.17 |  0.97 |     1353 |       4.8 |       230 |        1 |
# |   251 |  31.6  |  1.02 |     1338 |       4.5 |       230 |        1 |
# |   252 |  29.92 |  1.32 |     1422 |       4.8 |       230 |        1 |
# |   253 |  31.89 |  1.39 |     1416 |       4.5 |       230 |        1 |
# |   254 |  31.1  |  1.45 |     1414 |       4.5 |       230 |        0 |
# |   255 |  33.01 |  1.42 |     1393 |       4.6 |       230 |        0 |
# |   256 |  33.09 |  1.29 |     1253 |       4.8 |       230 |        1 |
# |   257 |  31.45 |  1.31 |     1341 |       4.8 |       230 |        1 |
# |   258 |  29.81 |  1.05 |     1359 |       4.7 |       230 |        0 |
# |   259 |  34.85 |  1.4  |     1352 |       4.5 |       230 |        0 |
# |   260 |  29.75 |  1.48 |     1344 |       4.5 |       230 |        0 |
# |   261 |  27.6  |  1.36 |     1344 |       5.1 |       230 |        0 |
# |   262 |  30.05 |  1.26 |     1341 |       4.9 |       230 |        0 |
# |   263 |  32.76 |  1.39 |     1390 |       4.5 |       230 |        0 |
# |   264 |  27.96 |  1.43 |     1378 |       4.7 |       230 |        0 |
# |   265 |  30.51 |  1.2  |     1338 |       4.5 |       230 |        1 |
# |   266 |  28.53 |  1.17 |     1417 |       4.7 |       230 |        0 |
# |   267 |  32.75 |  1.37 |     1402 |       4.6 |       230 |        0 |
# |   268 |  27.46 |  1.3  |     1415 |       4.7 |       230 |        1 |
# |   269 |  28.59 |  1.06 |     1379 |       4.7 |       230 |        1 |
# |   270 |  33.33 |  1.35 |     1386 |       4.8 |       230 |        1 |
# |   271 |  26.84 |  1.01 |     1412 |       4.6 |       230 |        1 |
# |   272 |  29.48 |  1.38 |     1336 |       4.6 |       230 |        0 |
# |   273 |  29.9  |  1.31 |     1403 |       4.7 |       230 |        0 |
# |   274 |  27.74 |  1.57 |     1457 |       4.5 |       230 |        0 |
# |   275 |  32.04 |  1.32 |     1425 |       4.7 |       230 |        1 |
# |   276 |  30.31 |  1.12 |     1379 |       4.7 |       230 |        0 |
# |   277 |  32.82 |  1.43 |      609 |       4.5 |       230 |        1 |
# |   278 |  31.65 |  1.32 |     1359 |       4.9 |       230 |        0 |
# |   279 |  31.5  |  1.15 |     1413 |       4.6 |       230 |        1 |
# |   280 |  33.91 |  1.39 |     1376 |       5.3 |       230 |        1 |
# |   281 |  28.82 |  1.43 |     1400 |       4.5 |       230 |        1 |
# |   282 |  32.75 |  1.55 |     1340 |       4.5 |       230 |        1 |
# |   283 |  32.03 |  1.23 |     1418 |       4.8 |       230 |        0 |
# |   284 |  29.71 |  1.44 |     1309 |       4.5 |       230 |        0 |
# |   285 |  31.14 |  1.43 |     1438 |       4.7 |       230 |        1 |
# |   286 |  32.52 |  1.44 |     1396 |       4.5 |       230 |        0 |
# |   287 |  26.46 |  1.34 |     1425 |       4.5 |       230 |        0 |
# |   288 |  29.83 |  1.42 |     1423 |       5.3 |       230 |        1 |
# |   289 |  31.53 |  1.4  |     1451 |       4.7 |       230 |        0 |
# |   290 |  27.39 |  0.91 |     1386 |       4.7 |       230 |        1 |
# |   291 |  31.51 |  0.85 |     1366 |       5.2 |       230 |        0 |
# |   292 |  30.33 |  1.44 |     1413 |       4.6 |       230 |        0 |
# |   293 |  29.81 |  1.16 |     1444 |       4.8 |       230 |        1 |
# |   294 |  32.58 |  1.46 |      570 |       4.7 |       230 |        1 |
# |   295 |  30.04 |  1.24 |     1342 |       4.9 |       230 |        0 |
# |   296 |  32.05 |  1.03 |     1359 |       4.7 |       230 |        1 |
# |   297 |  28.69 |  1.42 |     1381 |       4.5 |       230 |        0 |
# |   298 |  32.48 |  1.34 |     1359 |       4.6 |       230 |        1 |
# |   299 |  29.02 |  1.34 |     1405 |       4.5 |       230 |        0 |
# |   300 |  28.77 |  1.15 |     1411 |       4.5 |       230 |        0 |
# |   301 |  30.39 |  1.34 |     1372 |       4.7 |       230 |        1 |
# |   302 |  36.12 |  1.49 |      528 |       4.8 |       230 |        1 |
# |   303 |  30.18 |  1.33 |     1355 |       4.5 |       230 |        0 |
# |   304 |  30.27 |  1.18 |     1396 |       4.5 |       230 |        1 |
# |   305 |  35.2  |  1.45 |     1467 |       4.9 |       230 |        1 |
# |   306 |  32.36 |  1.33 |     1426 |       4.5 |       230 |        1 |
# |   307 |  31.99 |  1.34 |     1379 |       4.9 |       230 |        1 |
# |   308 |  31    |  0.95 |     1408 |       4.5 |       230 |        1 |
# |   309 |  31.38 |  0.97 |     1352 |       4.6 |       230 |        1 |
# |   310 |  29.68 |  1.42 |     1361 |       4.6 |       230 |        0 |
# |   311 |  29.52 |  1.28 |     1474 |       4.5 |       230 |        0 |
# |   312 |  32.18 |  1.17 |     1386 |       4.5 |       230 |        1 |
# |   313 |  31.67 |  1.38 |      592 |       4.7 |       229 |        1 |
# |   314 |  28.72 |  1.04 |     1423 |       4.5 |       230 |        0 |
# |   315 |  28.95 |  1.35 |     1446 |       4.8 |       230 |        1 |
# |   316 |  31.69 |  1.39 |     1396 |       4.6 |       230 |        0 |
# |   317 |  26.8  |  1.27 |     1359 |       4.5 |       230 |        0 |
# |   318 |  34.59 |  1.12 |     1456 |       5.1 |       230 |        1 |
# |   319 |  31.8  |  1.48 |     1342 |       4.5 |       230 |        0 |
# |   320 |  33.02 |  1.41 |     1375 |       4.5 |       230 |        1 |
# |   321 |  32.97 |  1.32 |     1379 |       4.8 |       230 |        1 |
# |   322 |  28.55 |  1.06 |     1474 |       4.5 |       230 |        0 |
# |   323 |  29.16 |  1.44 |     1393 |       4.6 |       230 |        0 |
# |   324 |  34.23 |  1.37 |     1360 |       4.5 |       230 |        1 |
# |   325 |  30.3  |  1.18 |     1416 |       4.8 |       230 |        1 |
# |   326 |  27.11 |  1.49 |     1345 |       4.8 |       230 |        1 |
# |   327 |  32.87 |  1.49 |     1445 |       4.6 |       230 |        1 |
# |   328 |  35.98 |  1.44 |     1331 |       4.5 |       230 |        1 |
# |   329 |  30.74 |  1.34 |     1365 |       4.5 |       230 |        0 |
# |   330 |  29.78 |  1.27 |     1407 |       4.9 |       230 |        0 |
# |   331 |  32.62 |  1.49 |     1407 |       4.8 |       230 |        1 |
# |   332 |  32.18 |  1.43 |     1336 |       4.5 |       230 |        1 |
# |   333 |  33.73 |  1.5  |     1450 |       4.6 |       230 |        1 |
# |   334 |  30.56 |  1.44 |     1419 |       4.8 |       230 |        0 |
# |   335 |  30.64 |  1.31 |     1346 |       4.5 |       230 |        1 |
# |   336 |  33.56 |  1.5  |     1431 |       4.7 |       230 |        0 |
# |   337 |  31.75 |  0.96 |     1333 |       4.5 |       230 |        0 |
# |   338 |  30.68 |  1.28 |     1419 |       4.5 |       230 |        1 |
# |   339 |  32.38 |  1.35 |     1428 |       4.5 |       230 |        0 |
# |   340 |  28.84 |  1.36 |     1407 |       4.5 |       230 |        0 |
# |   341 |  28.65 |  1.51 |     1356 |       4.5 |       230 |        0 |
# |   342 |  31.72 |  1.39 |     1397 |       4.8 |       230 |        1 |
# |   343 |  32.45 |  1.29 |     1420 |       4.5 |       230 |        1 |
# |   344 |  30.32 |  1.39 |     1385 |       4.5 |       230 |        0 |
# |   345 |  30.99 |  1.43 |     1474 |       4.5 |       230 |        0 |
# |   346 |  29.18 |  1.47 |     1363 |       4.5 |       230 |        1 |
# |   347 |  29.35 |  1.42 |     1352 |       4.5 |       230 |        1 |
# |   348 |  32.1  |  1.45 |     1425 |       4.5 |       230 |        0 |
# |   349 |  32.63 |  1.28 |     1349 |       4.8 |       230 |        0 |
# |   350 |  29.89 |  1.28 |     1406 |       4.5 |       230 |        0 |
# |   351 |  27.57 |  1.36 |     1399 |       4.5 |       230 |        1 |
# |   352 |  34.78 |  1.35 |     1347 |       4.8 |       230 |        1 |
# |   353 |  33.57 |  1.37 |     1431 |       5   |       230 |        1 |
# |   354 |  29.69 |  1.41 |     1316 |       4.5 |       230 |        0 |
# |   355 |  30.73 |  1.5  |     1352 |       4.8 |       230 |        1 |
# |   356 |  35.35 |  1.04 |     1367 |       4.5 |       230 |        1 |
# |   357 |  31.62 |  1.33 |     1460 |       4.8 |       230 |        1 |
# |   358 |  33.57 |  1.47 |     1450 |       4.6 |       230 |        0 |
# |   359 |  31.78 |  1.44 |     1437 |       4.7 |       230 |        1 |
# |   360 |  31.52 |  1.37 |     1395 |       4.5 |       230 |        0 |
# |   361 |  31.71 |  1.3  |     1350 |       4.6 |       230 |        0 |
# |   362 |  29.18 |  1.29 |     1414 |       5   |       230 |        1 |
# |   363 |  31    |  1.31 |     1417 |       4.7 |       230 |        0 |
# |   364 |  31.75 |  1.33 |     1377 |       4.9 |       230 |        1 |
# |   365 |  30.14 |  1.22 |     1368 |       4.8 |       230 |        1 |
# |   366 |  29.7  |  1.38 |     1436 |       4.7 |       230 |        0 |
# |   367 |  32.66 |  1.41 |     1389 |       4.9 |       230 |        1 |
# |   368 |  29.5  |  1.35 |     1367 |       4.8 |       230 |        0 |
# |   369 |  29.94 |  1.01 |     1334 |       4.5 |       230 |        0 |
# |   370 |  30.06 |  1.51 |     1417 |       4.5 |       230 |        0 |
# |   371 |  32.95 |  1.38 |     1427 |       4.6 |       230 |        1 |
# |   372 |  33.05 |  1.31 |     1398 |       4.5 |       230 |        1 |
# |   373 |  28.13 |  1.31 |     1417 |       4.5 |       230 |        0 |
# |   374 |  27.78 |  1.29 |     1383 |       4.5 |       230 |        0 |
# |   375 |  31.6  |  1    |     1413 |       4.8 |       230 |        1 |
# |   376 |  33.94 |  1.24 |     1364 |       4.5 |       230 |        0 |
# |   377 |  26.12 |  1.1  |     1409 |       4.9 |       230 |        0 |
# |   378 |  29.6  |  1.4  |     1375 |       4.5 |       230 |        1 |
# |   379 |  29.7  |  1    |     1445 |       4.5 |       230 |        1 |
# |   380 |  33.93 |  1.27 |     1444 |       4.8 |       230 |        1 |
# |   381 |  30.34 |  1.4  |     1341 |       4.7 |       230 |        0 |
# |   382 |  29.81 |  1.14 |     1443 |       4.5 |       230 |        0 |
# |   383 |  29.25 |  1.33 |     1402 |       4.5 |       230 |        1 |
# |   384 |  29.62 |  1.37 |     1340 |       4.5 |       230 |        0 |
# |   385 |  30.25 |  1.3  |     1420 |       4.5 |       230 |        0 |
# |   386 |  29.05 |  1.07 |     1385 |       4.5 |       230 |        0 |
# |   387 |  30.46 |  1.39 |     1474 |       4.7 |       230 |        0 |
# |   388 |  30.45 |  1.47 |     1440 |       4.7 |       230 |        1 |
# |   389 |  31.82 |  1.46 |     1394 |       4.9 |       230 |        0 |
# |   390 |  31.84 |  1.53 |     1462 |       5.1 |       230 |        0 |
# |   391 |  32.11 |  1.14 |     1323 |       4.5 |       230 |        1 |
# |   392 |  30.05 |  1.39 |     1412 |       4.5 |       230 |        1 |
# |   393 |  27.76 |  1.38 |     1409 |       4.8 |       230 |        1 |
# |   394 |  30.07 |  1.44 |     1436 |       4.5 |       230 |        0 |
# |   395 |  29.27 |  1.46 |     1410 |       4.7 |       230 |        0 |
# |   396 |  29.2  |  1.36 |     1364 |       4.7 |       230 |        1 |
# |   397 |  31.08 |  1.45 |     1364 |       4.6 |       230 |        0 |
# |   398 |  30.31 |  1.43 |     1410 |       4.7 |       230 |        1 |
# |   399 |  30.31 |  1.34 |     1421 |       4.5 |       230 |        0 |
# |   400 |  31.81 |  1.25 |     1365 |       5   |       230 |        1 |
# |   401 |  36.33 |  1.37 |     1384 |       4.6 |       230 |        0 |
# |   402 |  31.41 |  1.38 |     1421 |       4.6 |       230 |        1 |
# |   403 |  33.19 |  1.41 |     1411 |       4.8 |       230 |        1 |
# |   404 |  28.73 |  1.39 |     1391 |       4.8 |       230 |        0 |
# |   405 |  32.79 |  1.47 |     1357 |       4.5 |       230 |        0 |
# |   406 |  30.2  |  1.46 |     1462 |       4.8 |       230 |        1 |
# |   407 |  31.63 |  1.36 |     1464 |       4.7 |       230 |        1 |
# |   408 |  28.78 |  1.4  |     1458 |       4.5 |       230 |        0 |
# |   409 |  32.15 |  1.33 |     1430 |       4.5 |       230 |        0 |
# |   410 |  33.34 |  1.11 |     1371 |       4.9 |       230 |        1 |
# |   411 |  29.69 |  1.34 |     1317 |       5   |       230 |        1 |
# |   412 |  32.86 |  1.3  |     1388 |       4.7 |       230 |        1 |
# |   413 |  30.58 |  1.5  |     1430 |       4.6 |       230 |        0 |
# |   414 |  30.37 |  1.41 |     1474 |       4.6 |       230 |        0 |
# |   415 |  29.88 |  1.45 |     1277 |       4.5 |       230 |        0 |
# |   416 |  31.59 |  1.44 |     1367 |       4.5 |       230 |        1 |
# |   417 |  27.97 |  1.31 |     1355 |       4.5 |       230 |        0 |
# |   418 |  31.54 |  1.43 |     1474 |       4.8 |       230 |        0 |
# |   419 |  26.54 |  1.47 |     1407 |       4.7 |       230 |        0 |
# |   420 |  30.93 |  1.41 |     1385 |       4.5 |       230 |        0 |
# |   421 |  26.66 |  1.41 |     1398 |       4.5 |       230 |        0 |
# |   422 |  32.26 |  1.36 |     1436 |       4.5 |       230 |        0 |
# |   423 |  32.59 |  1.41 |     1453 |       4.9 |       230 |        0 |
# |   424 |  29.57 |  1.39 |     1400 |       4.5 |       230 |        1 |
# |   425 |  33.69 |  1.24 |     1349 |       5.5 |       230 |        1 |
# |   426 |  27.92 |  0.96 |     1380 |       4.9 |       230 |        1 |
# |   427 |  32.99 |  1.31 |     1355 |       4.7 |       230 |        1 |
# |   428 |  32.79 |  1.54 |     1459 |       4.8 |       230 |        1 |
# |   429 |  26.41 |  1.16 |     1332 |       4.7 |       230 |        1 |
# |   430 |  31.77 |  1.41 |     1342 |       4.5 |       230 |        0 |
# |   431 |  31.72 |  1.37 |     1418 |       5.1 |       230 |        1 |
# |   432 |  25.63 |  1.34 |     1363 |       4.6 |       230 |        1 |
# |   433 |  31.92 |  1.36 |     1474 |       4.8 |       230 |        1 |
# |   434 |  28.43 |  1.05 |     1431 |       4.8 |       230 |        1 |
# |   435 |  28.65 |  1.43 |     1395 |       4.6 |       230 |        0 |
# |   436 |  25.59 |  1.39 |     1466 |       4.8 |       230 |        0 |
# |   437 |  29.61 |  1.1  |     1387 |       4.5 |       230 |        0 |
# |   438 |  29.89 |  1.42 |     1474 |       4.8 |       230 |        0 |
# |   439 |  28.35 |  1.18 |     1385 |       4.5 |       230 |        0 |
# |   440 |  34.73 |  1.12 |     1399 |       4.7 |       230 |        1 |
# |   441 |  27.88 |  1.31 |     1386 |       4.7 |       230 |        0 |
# |   442 |  31.21 |  1.15 |     1424 |       4.5 |       230 |        0 |
# |   443 |  32.33 |  1.37 |      598 |       5.1 |       230 |        1 |
# |   444 |  32.05 |  1.14 |     1428 |       4.5 |       230 |        1 |
# |   445 |  25.4  |  1.34 |     1458 |       4.8 |       230 |        0 |
# |   446 |  32.39 |  1.34 |     1409 |       4.7 |       230 |        0 |
# |   447 |  28.89 |  1.44 |     1424 |       4.9 |       230 |        0 |
# |   448 |  26.42 |  1.32 |     1248 |       4.7 |       230 |        0 |
# |   449 |  31.67 |  1.37 |     1381 |       4.5 |       230 |        1 |
# |   450 |  31.87 |  1.56 |     1408 |       4.8 |       230 |        1 |
# |   451 |  30.2  |  1.54 |     1474 |       4.5 |       230 |        0 |
# |   452 |  32.85 |  1.09 |     1326 |       4.5 |       230 |        1 |
# |   453 |  30.22 |  1.38 |     1378 |       5.1 |       230 |        1 |
# |   454 |  31.6  |  1.34 |     1361 |       5.1 |       230 |        0 |
# |   455 |  35.13 |  1.38 |     1410 |       5.1 |       230 |        1 |
# |   456 |  30.3  |  1.43 |     1332 |       4.7 |       230 |        1 |
# |   457 |  29.1  |  1.44 |     1367 |       4.5 |       230 |        0 |
# |   458 |  28.75 |  1.39 |     1402 |       4.6 |       230 |        0 |
# |   459 |  31.99 |  1.36 |     1335 |       4.5 |       230 |        1 |
# |   460 |  36.08 |  1.4  |     1395 |       4.5 |       230 |        0 |
# |   461 |  30.11 |  1.48 |     1273 |       4.8 |       230 |        1 |
# |   462 |  36.29 |  0.97 |     1442 |       4.5 |       230 |        1 |
# |   463 |  33.85 |  1.33 |      584 |       5.1 |       230 |        1 |
# |   464 |  25.4  |  1.4  |     1306 |       4.5 |       230 |        0 |
# |   465 |  27.85 |  1.4  |     1408 |       4.5 |       230 |        1 |
# |   466 |  29.07 |  1.43 |     1452 |       4.5 |       230 |        0 |
# |   467 |  33.04 |  1.41 |     1331 |       4.9 |       230 |        1 |
# |   468 |  33.49 |  1.47 |     1463 |       4.5 |       230 |        1 |
# |   469 |  31.73 |  1.52 |      575 |       4.6 |       230 |        1 |
# |   470 |  30.36 |  1.39 |     1414 |       5.1 |       230 |        1 |
# |   471 |  31.55 |  1.19 |     1415 |       4.5 |       230 |        0 |
# |   472 |  28.86 |  1.28 |     1375 |       5   |       230 |        1 |
# |   473 |  30.9  |  1.42 |     1453 |       4.5 |       230 |        0 |
# |   474 |  31.08 |  1.34 |     1378 |       4.7 |       230 |        1 |
# |   475 |  30.96 |  1.36 |     1427 |       4.5 |       230 |        0 |
# |   476 |  32.31 |  1.11 |     1450 |       4.9 |       230 |        1 |
# |   477 |  31.68 |  1.45 |     1373 |       4.7 |       230 |        0 |
# |   478 |  30.27 |  1.34 |     1410 |       5.1 |       230 |        1 |
# |   479 |  33.09 |  1.48 |     1379 |       4.6 |       230 |        0 |
# |   480 |  33    |  1.46 |     1387 |       4.5 |       230 |        1 |
# |   481 |  29.42 |  1.34 |     1375 |       4.7 |       230 |        0 |
# |   482 |  35.06 |  1.39 |     1369 |       4.6 |       230 |        1 |
# |   483 |  30.89 |  1.38 |     1403 |       4.7 |       230 |        1 |
# |   484 |  30    |  1.44 |     1431 |       4.8 |       230 |        0 |
# |   485 |  33.63 |  1.39 |     1474 |       4.5 |       230 |        1 |
# |   486 |  31.36 |  1.5  |     1436 |       5   |       230 |        1 |
# |   487 |  28.21 |  1.05 |     1393 |       4.5 |       230 |        0 |
# |   488 |  29.7  |  1.38 |     1324 |       4.5 |       230 |        0 |
# |   489 |  28.96 |  1.39 |     1464 |       4.7 |       230 |        0 |
# |   490 |  29.42 |  1.55 |     1425 |       4.6 |       230 |        1 |
# |   491 |  31.14 |  1.51 |     1435 |       4.6 |       230 |        1 |
# |   492 |  29.28 |  1.44 |     1409 |       4.6 |       230 |        0 |
# |   493 |  29.77 |  1.4  |     1273 |       4.7 |       230 |        0 |
# |   494 |  33.04 |  0.93 |     1334 |       4.5 |       230 |        0 |
# |   495 |  27    |  1.18 |     1384 |       4.8 |       230 |        0 |
# |   496 |  28.72 |  1.45 |     1332 |       4.6 |       230 |        0 |
# |   497 |  29.91 |  1.37 |     1406 |       4.5 |       230 |        0 |
# |   498 |  29.08 |  1.43 |     1346 |       4.5 |       230 |        1 |
# |   499 |  30.71 |  1.41 |     1374 |       4.5 |       230 |        1 |
# |   500 |  26.84 |  1.28 |     1474 |       4.5 |       230 |        0 |
# |   501 |  28.48 |  1.18 |     1389 |       4.5 |       230 |        0 |
# |   502 |  30.29 |  1.39 |     1474 |       4.5 |       230 |        1 |
# |   503 |  31.19 |  1.33 |     1335 |       4.5 |       230 |        1 |
# |   504 |  34.11 |  1.1  |     1428 |       4.5 |       230 |        1 |
# |   505 |  33.43 |  0.93 |     1332 |       5   |       230 |        1 |
# |   506 |  27.16 |  1.1  |     1427 |       4.5 |       230 |        1 |
# |   507 |  30.74 |  1.45 |     1390 |       4.5 |       230 |        0 |
# |   508 |  30.43 |  1.41 |     1431 |       4.5 |       230 |        0 |
# |   509 |  32.86 |  1.52 |     1452 |       4.8 |       230 |        1 |
# |   510 |  33.67 |  1.4  |     1474 |       4.7 |       230 |        0 |
# |   511 |  31.94 |  1.28 |     1433 |       4.5 |       230 |        0 |
# |   512 |  28.11 |  1.32 |     1351 |       4.7 |       230 |        0 |
# |   513 |  27.98 |  1.34 |     1474 |       4.5 |       230 |        0 |
# |   514 |  31.92 |  1.24 |     1474 |       4.5 |       230 |        0 |
# |   515 |  29.56 |  1.34 |     1418 |       4.6 |       230 |        0 |
# |   516 |  29.27 |  1.37 |     1441 |       4.5 |       230 |        0 |
# |   517 |  30.03 |  1.35 |     1384 |       4.8 |       230 |        1 |
# |   518 |  29.57 |  1.39 |     1398 |       5.1 |       230 |        1 |
# |   519 |  33.29 |  1.36 |     1406 |       4.7 |       230 |        1 |
# |   520 |  32.73 |  1.27 |     1399 |       4.5 |       230 |        1 |
# |   521 |  36.47 |  1.47 |      575 |       4.7 |       230 |        1 |
# |   522 |  32.21 |  1.27 |     1474 |       4.8 |       230 |        0 |
# |   523 |  31.79 |  1.37 |     1340 |       4.5 |       230 |        0 |
# |   524 |  33.13 |  1.16 |     1388 |       4.6 |       230 |        1 |
# |   525 |  28.96 |  1.49 |     1429 |       4.5 |       230 |        0 |
# |   526 |  31.47 |  1.44 |     1416 |       4.5 |       230 |        1 |
# |   527 |  33.07 |  1.39 |     1384 |       4.9 |       230 |        1 |
# |   528 |  32.08 |  1.3  |     1447 |       4.7 |       230 |        1 |
# |   529 |  27.88 |  1.28 |     1300 |       4.9 |       230 |        1 |
# |   530 |  33.26 |  1.08 |     1303 |       4.5 |       230 |        1 |
# |   531 |  30.1  |  1.45 |     1361 |       4.5 |       230 |        0 |
# |   532 |  27.9  |  1.33 |     1406 |       4.6 |       230 |        1 |
# |   533 |  31.12 |  1.37 |     1466 |       4.5 |       230 |        1 |
# |   534 |  30.53 |  1.39 |     1418 |       4.9 |       230 |        1 |
# |   535 |  28.36 |  1.19 |     1372 |       4.5 |       230 |        0 |
# |   536 |  30.45 |  1.48 |     1441 |       4.7 |       230 |        0 |
# |   537 |  29.54 |  1.52 |     1399 |       4.6 |       230 |        0 |
# |   538 |  30.79 |  1.33 |     1411 |       4.9 |       230 |        0 |
# |   539 |  31.24 |  1.06 |     1376 |       4.6 |       230 |        0 |
# |   540 |  25.72 |  1.37 |     1332 |       4.7 |       230 |        0 |
# |   541 |  28.14 |  1.32 |     1398 |       5.1 |       230 |        1 |
# |   542 |  35.32 |  1.41 |      300 |       4.8 |       230 |        1 |
# |   543 |  30.07 |  1.49 |     1419 |       4.6 |       230 |        0 |
# |   544 |  26.53 |  1.4  |     1384 |       4.5 |       230 |        1 |
# |   545 |  32.11 |  1.39 |     1376 |       5   |       230 |        1 |
# |   546 |  32.01 |  1.44 |     1446 |       4.7 |       230 |        1 |
# |   547 |  34.19 |  1.37 |      454 |       5.1 |       230 |        1 |
# |   548 |  28.52 |  1.27 |     1462 |       4.5 |       230 |        1 |
# |   549 |  32.58 |  0.92 |     1428 |       4.7 |       230 |        1 |
# |   550 |  29.1  |  0.9  |     1274 |       4.6 |       230 |        0 |
# |   551 |  30.96 |  0.92 |     1340 |       4.5 |       230 |        0 |
# |   552 |  31.98 |  1.37 |     1389 |       4.8 |       230 |        1 |
# |   553 |  32.42 |  1.44 |     1382 |       4.6 |       230 |        1 |
# |   554 |  28.87 |  1.25 |     1331 |       4.9 |       230 |        0 |
# |   555 |  31.39 |  1.4  |     1451 |       4.5 |       230 |        0 |
# |   556 |  31.61 |  1.32 |     1334 |       4.5 |       230 |        1 |
# |   557 |  30.38 |  1.05 |     1427 |       4.5 |       230 |        1 |
# |   558 |  31.19 |  1.28 |     1382 |       4.9 |       230 |        0 |
# |   559 |  27.87 |  0.97 |     1359 |       4.6 |       230 |        0 |
# |   560 |  25.93 |  1.45 |     1375 |       5   |       230 |        0 |
# |   561 |  33.91 |  1.44 |     1399 |       4.8 |       230 |        1 |
# |   562 |  30.03 |  1.51 |     1390 |       4.6 |       230 |        0 |
# |   563 |  34.67 |  1.47 |     1474 |       4.6 |       230 |        1 |
# |   564 |  31.66 |  1.35 |     1444 |       4.5 |       230 |        0 |
# |   565 |  30.22 |  1    |     1424 |       5   |       230 |        1 |
# |   566 |  29.22 |  1.02 |     1432 |       4.7 |       230 |        0 |
# |   567 |  32.45 |  1.4  |     1369 |       4.8 |       230 |        1 |
# |   568 |  31.56 |  1.39 |     1458 |       4.5 |       230 |        0 |
# |   569 |  26.74 |  1.12 |     1318 |       4.8 |       230 |        0 |
# |   570 |  30.83 |  1.29 |     1373 |       4.6 |       230 |        0 |
# |   571 |  32.23 |  1.35 |     1397 |       4.6 |       230 |        0 |
# |   572 |  28.64 |  1.34 |     1395 |       4.7 |       230 |        1 |
# |   573 |  32.46 |  1.2  |     1417 |       4.5 |       230 |        1 |
# |   574 |  33    |  1.22 |     1347 |       4.8 |       230 |        0 |
# |   575 |  27.32 |  1.18 |     1389 |       4.5 |       230 |        0 |
# |   576 |  33.72 |  1.3  |     1402 |       4.5 |       230 |        1 |
# |   577 |  29.95 |  1.29 |     1360 |       4.6 |       230 |        0 |
# |   578 |  32.79 |  1.11 |     1449 |       4.8 |       230 |        1 |
# |   579 |  28.73 |  1.01 |     1367 |       4.5 |       230 |        0 |
# |   580 |  30.8  |  1.35 |     1464 |       4.6 |       230 |        1 |
# |   581 |  29.93 |  0.95 |     1400 |       4.6 |       230 |        1 |
# |   582 |  28.2  |  1.28 |     1455 |       4.5 |       230 |        0 |
# |   583 |  26.52 |  1.4  |     1403 |       4.7 |       230 |        0 |
# |   584 |  32.35 |  1.55 |     1396 |       4.6 |       230 |        1 |
# |   585 |  32.2  |  1.23 |     1369 |       4.5 |       230 |        1 |
# |   586 |  30.9  |  1.43 |     1379 |       4.5 |       230 |        0 |
# |   587 |  29.29 |  1.59 |     1456 |       4.9 |       230 |        1 |
# |   588 |  32.98 |  1.44 |     1462 |       4.5 |       230 |        0 |
# |   589 |  33.85 |  1.21 |      600 |       4.7 |       230 |        1 |
# |   590 |  31.78 |  1.36 |     1395 |       4.5 |       230 |        0 |
# |   591 |  30.91 |  1.17 |     1389 |       4.9 |       230 |        1 |
# |   592 |  27.09 |  1.39 |     1426 |       4.5 |       230 |        0 |
# |   593 |  32.86 |  1.44 |     1428 |       4.5 |       230 |        1 |
# |   594 |  28.65 |  1.36 |     1474 |       4.6 |       230 |        0 |
# |   595 |  28    |  1.39 |     1451 |       4.7 |       230 |        0 |
# |   596 |  29.92 |  1.41 |     1436 |       4.8 |       230 |        0 |
# |   597 |  32.31 |  1.09 |     1332 |       4.6 |       230 |        1 |
# |   598 |  26.59 |  1.36 |     1349 |       4.5 |       230 |        0 |
# |   599 |  33.75 |  1.25 |     1329 |       4.6 |       230 |        0 |
# |   600 |  32.93 |  1.28 |     1380 |       5   |       230 |        0 |
# |   601 |  31.95 |  1.31 |     1326 |       4.7 |       230 |        0 |
# |   602 |  30.02 |  1.22 |     1453 |       4.5 |       230 |        0 |
# |   603 |  30.17 |  1.21 |     1392 |       4.5 |       230 |        0 |
# |   604 |  28.83 |  1.24 |     1427 |       4.5 |       230 |        0 |
# |   605 |  28.19 |  1.39 |     1399 |       4.7 |       230 |        0 |
# |   606 |  33.48 |  1.35 |     1451 |       4.9 |       230 |        0 |
# |   607 |  30.97 |  1.43 |     1328 |       4.8 |       230 |        1 |
# |   608 |  27.97 |  1.43 |     1431 |       4.5 |       230 |        0 |
# |   609 |  31.79 |  0.95 |     1446 |       4.5 |       230 |        1 |
# |   610 |  28.64 |  1.42 |     1333 |       4.5 |       230 |        0 |
# |   611 |  30.31 |  1.15 |     1369 |       4.5 |       230 |        0 |
# |   612 |  31.43 |  1.61 |     1423 |       4.6 |       230 |        0 |
# |   613 |  35.68 |  1.28 |     1474 |       4.7 |       230 |        0 |
# |   614 |  32.03 |  1.19 |     1416 |       4.8 |       230 |        1 |
# |   615 |  30.34 |  1.15 |     1350 |       4.8 |       230 |        0 |
# |   616 |  35.41 |  1.38 |     1346 |       4.8 |       230 |        1 |
# |   617 |  31.37 |  1.29 |     1322 |       4.9 |       230 |        1 |
# |   618 |  29.67 |  1.37 |     1388 |       4.8 |       230 |        1 |
# |   619 |  27.25 |  1.43 |     1350 |       4.5 |       230 |        0 |
# |   620 |  31.46 |  1.03 |     1374 |       5   |       230 |        1 |
# |   621 |  25.4  |  1.22 |     1412 |       4.5 |       230 |        0 |
# |   622 |  33.4  |  1.46 |     1342 |       4.5 |       230 |        1 |
# |   623 |  33.23 |  1.07 |     1388 |       4.6 |       230 |        0 |
# |   624 |  33.31 |  0.88 |     1356 |       5.1 |       230 |        1 |
# |   625 |  29.3  |  1.43 |     1428 |       4.7 |       230 |        1 |
# |   626 |  37.31 |  1.29 |      647 |       4.6 |       230 |        1 |
# |   627 |  30.7  |  1.29 |     1368 |       4.5 |       230 |        0 |
# |   628 |  27.85 |  1.52 |     1443 |       4.5 |       230 |        0 |
# |   629 |  32.89 |  1.14 |     1384 |       4.6 |       230 |        0 |
# |   630 |  29.32 |  1.38 |     1361 |       4.7 |       230 |        0 |
# |   631 |  28.06 |  1.22 |     1385 |       4.5 |       230 |        0 |
# |   632 |  27.92 |  1.36 |     1341 |       4.5 |       230 |        0 |
# |   633 |  32.95 |  1.36 |     1337 |       4.5 |       230 |        0 |
# |   634 |  35.53 |  1.06 |     1462 |       4.6 |       230 |        1 |
# |   635 |  31.63 |  1.25 |     1395 |       4.9 |       230 |        0 |
# |   636 |  32.66 |  1.32 |     1404 |       4.6 |       230 |        0 |
# |   637 |  27.74 |  1.32 |     1421 |       4.5 |       230 |        0 |
# |   638 |  32    |  1.43 |     1389 |       4.5 |       230 |        1 |
# |   639 |  33.36 |  1.33 |     1349 |       5.3 |       230 |        1 |
# |   640 |  29.43 |  1.36 |     1436 |       4.7 |       230 |        0 |
# |   641 |  32.55 |  1.24 |     1420 |       4.8 |       230 |        1 |
# |   642 |  31.33 |  1.39 |     1452 |       4.6 |       230 |        0 |
# |   643 |  31.15 |  1.43 |     1416 |       4.9 |       230 |        0 |
# |   644 |  32.17 |  1.32 |     1385 |       4.5 |       230 |        0 |
# |   645 |  30.12 |  1.46 |     1466 |       4.8 |       230 |        1 |
# |   646 |  31.65 |  1.4  |     1322 |       4.7 |       230 |        1 |
# |   647 |  33.2  |  1.4  |     1405 |       4.7 |       230 |        0 |
# |   648 |  30.6  |  1.42 |     1395 |       4.6 |       230 |        0 |
# |   649 |  33.78 |  1.25 |     1389 |       4.9 |       230 |        0 |
# |   650 |  30.49 |  1.41 |     1437 |       4.5 |       230 |        0 |
# |   651 |  30.65 |  1.37 |     1318 |       5   |       230 |        0 |
# |   652 |  31.98 |  1.38 |     1369 |       4.5 |       230 |        0 |
# |   653 |  31.11 |  1.41 |     1394 |       4.8 |       230 |        1 |
# |   654 |  26.97 |  1.42 |     1450 |       4.5 |       230 |        0 |
# ...
# | 19781 |  30.74 |  1.43 |     1425 |       4.5 |       230 |        0 |
# | 19782 |  27.5  |  1.43 |     1394 |       4.7 |       230 |        1 |
# | 19783 |  31.49 |  1.56 |     1432 |       4.7 |       230 |        1 |
# | 19984 |  28.5  |  1.39 |     1419 |       4.5 |       230 |        0 |
# | 19985 |  29.62 |  1.22 |     1304 |       4.5 |       230 |        0 |
# | 19986 |  32.24 |  1.04 |     1426 |       5   |       230 |        0 |
# | 19987 |  32.52 |  1.17 |     1395 |       4.6 |       230 |        1 |
# | 19988 |  28.3  |  1.44 |     1366 |       4.8 |       230 |        0 |
# | 19989 |  34.45 |  1.4  |     1441 |       4.5 |       230 |        0 |
# | 19990 |  31.94 |  1.03 |     1293 |       5   |       230 |        0 |
# | 19991 |  33.24 |  1.39 |     1381 |       4.6 |       230 |        0 |
# | 19992 |  27.5  |  1.46 |     1474 |       4.5 |       230 |        0 |
# | 19993 |  31.38 |  1.52 |     1384 |       5.1 |       230 |        1 |
# | 19994 |  30.76 |  1.19 |     1415 |       4.9 |       230 |        0 |
# | 19995 |  32.64 |  1.35 |     1452 |       4.6 |       230 |        0 |
# | 19996 |  26.06 |  1.37 |     1351 |       4.6 |       230 |        0 |
# | 19997 |  31.52 |  1.29 |     1381 |       4.5 |       230 |        1 |
# | 19998 |  31.55 |  0.97 |     1406 |       4.9 |       230 |        1 |
# | 19999 |  29.64 |  1.27 |     1474 |       4.5 |       230 |        0 |

# %%
data_final.describe()
# Out:
#                temp           vib        speed        current       voltage  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean      30.879779      1.311554   1373.883100      4.732350    229.959850
# std        2.259422      0.151996    152.007136      1.058662      0.611029
# min       25.400000      0.820000    296.000000      4.500000    220.000000
# 25%       29.330000      1.250000   1362.000000      4.500000    230.000000
# 50%       30.860000      1.350000   1398.000000      4.600000    230.000000
# 75%       32.410000      1.410000   1433.000000      4.800000    230.000000
# max       56.300000      1.680000   1474.000000     21.000000    230.000000
#
#             output
# count  20000.00000
# mean       0.44780
# std        0.49728
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        1.00000
# max        1.00000
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *['temp'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_1, *['vib'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_2, *['speed '], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_3, *['current'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_4, *['temp'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_5, *['vib'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_6, *['speed '], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_7, *['current'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 6 * figscale, 6 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(_df_8, *[[['temp', 'vib'], ['vib', 'speed '], ['speed ', 'current'], ['current', 'voltage']]], **{})
# chart

# %%
# Plotting frequency on bar graph
import matplotlib.pyplot as plt
# %matplotlib inline

count_classes = pd.value_counts(data_final['output'], sort = True).sort_index()
count_classes.plot(kind = 'bar',color=['green','red'])
plt.title("Errors")
plt.xlabel("Error\n[0:No Error 1:Error]")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Visualizing the efficiency

# %%
# Splitting into train and test in 4:1
from sklearn.model_selection import train_test_split
train, test=train_test_split(data_final,test_size=0.20,random_state=1)

# %%
# split train data into features and labels
x = train.drop('output', axis=1).values.astype(float)
y = train['output'].values.astype(float)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier

# %%
# Creating 10-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)

# %%
# Calling the classifier with 10 branches
rf_classifier = RandomForestClassifier(n_estimators=10, random_state=42)

# %%
# Performing cross-validation
scores = cross_val_score(rf_classifier, x, y, cv=kfold)

# %%
from sklearn.model_selection import cross_validate
from sklearn.metrics import f1_score, cohen_kappa_score, average_precision_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score, confusion_matrix, matthews_corrcoef, balanced_accuracy_score, make_scorer

# %%
# Define the evaluation metrics
scoring = {
    'F1-Score': make_scorer(f1_score, average='macro'),
    'Kappa-Score': make_scorer(cohen_kappa_score),
    'Average Precision Score': make_scorer(average_precision_score),
    'G-Mean': make_scorer(lambda y_true, y_pred: np.sqrt(accuracy_score(y_true, y_pred) * recall_score(y_true, y_pred, average='macro')), greater_is_better=True),
    'Accuracy': make_scorer(accuracy_score)
}

# %%
# Perform cross-validation and calculate evaluation metrics
scores = cross_validate(rf_classifier, x, y, cv=kfold, scoring=scoring)

# %%
# Print the evaluation metrics for each fold and the mean values
for metric in scores.keys():
    fold_scores = scores[metric]
    print(f"{metric}: {fold_scores}\n")
    print(f"Mean {metric}: {fold_scores.mean()}\n")
# Out:
# fit_time: [0.27273226 0.27323151 0.26046681 0.26486468 0.25850558 0.27465296
#  0.271245   0.26351404 0.26875472 0.26401472]
#
# Mean fit_time: 0.2671982288360596
#
# score_time: [0.01778436 0.01709533 0.01852822 0.01991987 0.01717186 0.02237058
#  0.01824284 0.01968026 0.02002573 0.01952791]
#
# Mean score_time: 0.019034695625305176
#
# test_F1-Score: [0.6251875  0.62596165 0.63171042 0.6154089  0.60724445 0.60890293
#  0.60007737 0.63413016 0.62480289 0.61041462]
#
# Mean test_F1-Score: 0.6183840871762297
#
# test_Kappa-Score: [0.25264794 0.26164307 0.2673543  0.23527395 0.22163015 0.22088091
#  0.2078397  0.2724486  0.25492522 0.22482613]
#
# Mean test_Kappa-Score: 0.2419469975238388
#
# test_Average Precision Score: [0.52729375 0.53479138 0.5293813  0.5213537  0.51635663 0.51516551
#  0.52444131 0.55388698 0.53715552 0.51758242]
#
# Mean test_Average Precision Score: 0.5277408511815779
#
# test_G-Mean: [0.63016841 0.63591307 0.63841591 0.62216517 0.61606494 0.61473502
#  0.60764888 0.63856652 0.63111341 0.61685347]
#
# Mean test_G-Mean: 0.6251644806538803
#
# test_Accuracy: [0.635625 0.644375 0.645625 0.62875  0.62375  0.620625 0.613125 0.6425
#  0.636875 0.623125]
#
# Mean test_Accuracy: 0.6314375

# %% [markdown]
# ## MODEL 1 - BINARY CLASSIFIER

# %%
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split

# %%
# Splitting the data into training and testing sets
train,test = train_test_split(data_final, test_size=0.2, random_state=42)

# %%
x_train = train.drop('output', axis=1)
y_train = train['output']
x_test = test.drop('output', axis=1)
y_test = test['output']

# %%
# Building the neural network model
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(5,)),  # Input layer
    tf.keras.layers.Dense(128, activation='relu'),  # Hidden layer with 128 units and ReLU activation
    tf.keras.layers.Dense(1, activation='sigmoid')  # Output layer with 1 unit and sigmoid activation
])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 128)               768
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 897 (3.50 KB)
# Trainable params: 897 (3.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Eval metrics
# Custom callback to collect training speed and convergence per epoch
from tensorflow.keras.callbacks import ModelCheckpoint, Callback
import time
class TrainingStatsCallback(Callback):
    def __init__(self):
        self.start_time = 0
        self.steps = 0
        self.speeds = []
        self.convergences = []

    def on_train_begin(self, logs=None):
        self.start_time = time.time()

    def on_train_batch_end(self, batch, logs=None):
        self.steps += 1

    def on_epoch_end(self, epoch, logs=None):
        if logs is not None:
            epoch_time = time.time() - self.start_time
            speed = epoch_time / self.steps
            self.speeds.append(speed)
            self.convergences.append(logs.get('loss'))
            self.steps = 0

# %%
# Define the model checkpoint
checkpoint = ModelCheckpoint('model.h5', monitor='loss', verbose=0, save_best_only=True, mode='min')

# Define the training stats callback
stats_callback = TrainingStatsCallback()

# Training the model
model.fit(x_train, y_train, epochs=100, batch_size=32, validation_split=0.1, callbacks=[checkpoint, stats_callback])  #increase epoches to 2000 to get accuracy around 82 percent
# Out:
# Epoch 1/100
# 450/450 [==============================] - 2s 5ms/step - loss: 0.6868 - accuracy: 0.6248 - val_loss: 0.6079 - val_accuracy: 0.6587
# Epoch 2/100
#  24/450 [>.............................] - ETA: 1s - loss: 0.6276 - accuracy: 0.6536
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 450/450 [==============================] - 2s 5ms/step - loss: 0.6438 - accuracy: 0.6409 - val_loss: 0.6430 - val_accuracy: 0.6400
# Epoch 3/100
# 450/450 [==============================] - 1s 3ms/step - loss: 0.6729 - accuracy: 0.6244 - val_loss: 0.6524 - val_accuracy: 0.6219
# Epoch 4/100
# 450/450 [==============================] - 1s 3ms/step - loss: 0.7167 - accuracy: 0.6103 - val_loss: 0.6933 - val_accuracy: 0.5813
# Epoch 5/100
# 450/450 [==============================] - 1s 3ms/step - loss: 0.6759 - accuracy: 0.6279 - val_loss: 0.6465 - val_accuracy: 0.6275
# Epoch 6/100
# 450/450 [==============================] - 1s 3ms/step - loss: 0.6661 - accuracy: 0.6308 - val_loss: 0.6186 - val_accuracy: 0.6469
# Epoch 7/100
# 450/450 [==============================] - 1s 3ms/step - loss: 0.6863 - accuracy: 0.6299 - val_loss: 0.8157 - val_accuracy: 0.5956
# Epoch 8/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.6815 - accuracy: 0.6216 - val_loss: 0.6124 - val_accuracy: 0.6569
# Epoch 9/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.6860 - accuracy: 0.6212 - val_loss: 0.5963 - val_accuracy: 0.6656
# Epoch 10/100
# 450/450 [==============================] - 2s 3ms/step - loss: 0.6473 - accuracy: 0.6389 - val_loss: 0.6381 - val_accuracy: 0.6288
# Epoch 11/100
# 450/450 [==============================] - 1s 3ms/step - loss: 0.6600 - accuracy: 0.6331 - val_loss: 0.6069 - val_accuracy: 0.6544
# Epoch 12/100
# 450/450 [==============================] - 1s 3ms/step - loss: 0.6612 - accuracy: 0.6361 - val_loss: 0.8459 - val_accuracy: 0.5019
# Epoch 13/100
# 450/450 [==============================] - 1s 3ms/step - loss: 0.6931 - accuracy: 0.6197 - val_loss: 0.6053 - val_accuracy: 0.6562
# Epoch 14/100
# 450/450 [==============================] - 1s 3ms/step - loss: 0.6750 - accuracy: 0.6226 - val_loss: 0.6819 - val_accuracy: 0.6237
# Epoch 15/100
# 450/450 [==============================] - 1s 3ms/step - loss: 0.6892 - accuracy: 0.6210 - val_loss: 0.7503 - val_accuracy: 0.6081
# Epoch 16/100
# 450/450 [==============================] - 1s 3ms/step - loss: 0.6844 - accuracy: 0.6183 - val_loss: 0.6636 - val_accuracy: 0.6294
# Epoch 17/100
# 450/450 [==============================] - 1s 3ms/step - loss: 0.6565 - accuracy: 0.6301 - val_loss: 0.6198 - val_accuracy: 0.6488
# Epoch 18/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.6567 - accuracy: 0.6366 - val_loss: 0.6183 - val_accuracy: 0.6494
# Epoch 19/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.6964 - accuracy: 0.6234 - val_loss: 0.5963 - val_accuracy: 0.6650
# Epoch 20/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.6758 - accuracy: 0.6252 - val_loss: 0.6009 - val_accuracy: 0.6587
# Epoch 21/100
# 450/450 [==============================] - 1s 3ms/step - loss: 0.6466 - accuracy: 0.6390 - val_loss: 0.5976 - val_accuracy: 0.6612
# Epoch 22/100
# 450/450 [==============================] - 1s 3ms/step - loss: 0.
100
# 450/450 [==============================] - 1s 3ms/step - loss: 0.6274 - accuracy: 0.6452 - val_loss: 0.6001 - val_accuracy: 0.6575
# Epoch 84/100
# 450/450 [==============================] - 1s 3ms/step - loss: 0.6332 - accuracy: 0.6374 - val_loss: 0.7077 - val_accuracy: 0.6094
# Epoch 85/100
# 450/450 [==============================] - 2s 3ms/step - loss: 0.6358 - accuracy: 0.6390 - val_loss: 0.6414 - val_accuracy: 0.6313
# Epoch 86/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.6500 - accuracy: 0.6315 - val_loss: 0.6200 - val_accuracy: 0.6400
# Epoch 87/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.6510 - accuracy: 0.6312 - val_loss: 0.6863 - val_accuracy: 0.6119
# Epoch 88/100
# 450/450 [==============================] - 2s 5ms/step - loss: 0.6272 - accuracy: 0.6424 - val_loss: 0.5948 - val_accuracy: 0.6794
# Epoch 89/100
# 450/450 [==============================] - 2s 6ms/step - loss: 0.6258 - accuracy: 0.6420 - val_loss: 0.6291 - val_accuracy: 0.6363
# Epoch 90/100
# 450/450 [==============================] - 2s 5ms/step - loss: 0.6284 - accuracy: 0.6452 - val_loss: 0.7296 - val_accuracy: 0.6006
# Epoch 91/100
# 450/450 [==============================] - 1s 3ms/step - loss: 0.6304 - accuracy: 0.6428 - val_loss: 0.6011 - val_accuracy: 0.6612
# Epoch 92/100
# 450/450 [==============================] - 1s 3ms/step - loss: 0.6428 - accuracy: 0.6344 - val_loss: 0.6357 - val_accuracy: 0.6244
# Epoch 93/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.6317 - accuracy: 0.6397 - val_loss: 0.7085 - val_accuracy: 0.5525
# Epoch 94/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.6319 - accuracy: 0.6403 - val_loss: 0.7086 - val_accuracy: 0.5537
# Epoch 95/100
# 450/450 [==============================] - 2s 4ms/step - loss: 0.6405 - accuracy: 0.6397 - val_loss: 0.6095 - val_accuracy: 0.6469
# Epoch 96/100
# 450/450 [==============================] - 1s 3ms/step - loss: 0.6258 - accuracy: 0.6413 - val_loss: 0.6784 - val_accuracy: 0.5806
# Epoch 97/100
# 450/450 [==============================] - 1s 3ms/step - loss: 0.6279 - accuracy: 0.6425 - val_loss: 0.6321 - val_accuracy: 0.6263
# Epoch 98/100
# 450/450 [==============================] - 1s 3ms/step - loss: 0.6308 - accuracy: 0.6436 - val_loss: 0.6200 - val_accuracy: 0.6406
# Epoch 99/100
# 450/450 [==============================] - 1s 3ms/step - loss: 0.6329 - accuracy: 0.6391 - val_loss: 0.6164 - val_accuracy: 0.6544
# Epoch 100/100
# 450/450 [==============================] - 1s 3ms/step - loss: 0.6313 - accuracy: 0.6413 - val_loss: 0.6277 - val_accuracy: 0.6381

# %%
# Training efficiency
# Plot the training speed and convergence per epoch
epochs = range(1, len(stats_callback.speeds) + 1)

plt.figure(figsize=(20, 10))
plt.subplot(1, 2, 1)
plt.plot(epochs, stats_callback.speeds, 'b-o')
plt.xlabel('Epochs')
plt.ylabel('Training Speed (seconds/step)')
plt.title('Training Speed per Epoch')

plt.subplot(1, 2, 2)
plt.plot(epochs, stats_callback.convergences, 'r-o')
plt.xlabel('Epochs')
plt.ylabel('Convergence')
plt.title('Convergence per Epoch')

plt.tight_layout()
plt.show()

# %%
# Evaluate the model on the test data
loss, accuracy = model.evaluate(x_train, y_train)
print(f"Test loss: {loss:.4f}")
print(f"Test accuracy: {accuracy:.4f}")
# Out:
# Test loss:  0.0098
# Test accuracy:  0.8123

# %%
# prediction
new_features = 5
inp  = list()
name = ['temp','vib','speed','current','voltage']
for i in range(5):
  print("Enter",name[i])
  g = input()
  inp.append(float(g))

prediction = model.predict(np.array(inp).reshape((1,5)))
predicted_class = (prediction < 0.5).astype(int)


print("Predicted Class:", predicted_class[0][0])
# Out:
# Enter temp
# 45
# Enter vib
# 24
# Enter speed
# 1400
# Enter current
# 4.3
# Enter voltage
# 220
# 1/1 [==============================] - 0s 18ms/step
# Predicted Class: 1
